# %%
import selenium
import pandas as pd
import time
# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# importing regex
import re

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-in-delhi/#city=10&pc=10&sc=-1&so=-1&filterbyadditional=2&pn=5&lcr=96&ldr=0&lir=0"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)
#Taking 1000 pages into consideration using for loop
for i in range(1000):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
pd.set_option("display.max_rows",None)

# %%
df=pd.DataFrame({'Model':Model[0:248],'Year':Year[0:248],'Price':Price[0:248],'KM_driven':KM_driven[0:248],'Fuel_Type':Fuel_Type[0:248],'Registration':Registration[0:248]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                         Renault Kwid 1.0 RXL Edition  2017      ₹ 3 Lakh
# 1                                    Hyundai i10 Magna  2008    ₹ 1.4 Lakh
# 2                        Maruti Suzuki Ertiga ZXi Plus  2019    ₹ 9.5 Lakh
# 3                      Ford EcoSport Trend + 1.5L TDCi  2017    ₹ 7.1 Lakh
# 4                  Hyundai Creta 1.6 SX Plus AT Petrol  2017  ₹ 10.75 Lakh
# 5               Mercedes-Benz GLS Grand Edition Diesel  2019     ₹ 81 Lakh
# 6                                      Honda Brio S MT  2012   ₹ 2.85 Lakh
# 7                                Volvo V40 D3 R-Design  2016   ₹ 17.5 Lakh
# 8                        Maruti Suzuki Swift DZire VDI  2014    ₹ 4.5 Lakh
# 9                            Renault Duster 110 PS RxL  2016      ₹ 5 Lakh
# 10                           Maruti Suzuki Celerio LXi  2014   ₹ 3.25 Lakh
# ...

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-in-mumbai/#city=3000&pc=3000&sc=-1&so=-1"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)
#Taking 1000 pages into consideration using for loop
for i in range(1000):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:246],'Year':Year[0:246],'Price':Price[0:246],'KM_driven':KM_driven[0:246],'Fuel_Type':Fuel_Type[0:246],'Registration':Registration[0:246]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0             Mercedes-Benz C-Class 200 CGI Avantgarde  2011  ₹ 12.58 Lakh
# 1                        Maruti Suzuki Wagon R 1.0 VXi  2013   ₹ 3.45 Lakh
# 2    Volkswagen Vento Highline Plus 1.2 (P) AT 16 A...  2016   ₹ 6.95 Lakh
# 3        Toyota Innova Crysta 2.4 VX 7 STR [2016-2020]  2019  ₹ 21.45 Lakh
# 4                         Maruti Suzuki Ciaz ZDi+ SHVS  2016   ₹ 7.11 Lakh
# 5                                  Honda Civic 1.8S MT  2009    ₹ 2.4 Lakh
# 6                               Honda Jazz V AT Petrol  2015   ₹ 5.75 Lakh
# 7                     Maruti Suzuki Dzire ZXi Plus AMT  2018   ₹ 7.25 Lakh
# 8                                  Hyundai Xcent S 1.2  2014    ₹ 4.2 Lakh
# 9                                      Nissan Sunny XV  2014   ₹ 4.25 Lakh
# 10                           Honda Amaze 1.2 SX i-VTEC  2016   ₹ 4.45 Lakh
# ...

# %%
import selenium
import pandas as pd
import time
# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# importing regex
import re

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-in-delhi/#city=10&pc=10&sc=-1&so=-1&filterbyadditional=2&car=10"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(500):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
pd.set_option("display.max_rows",None)

# %%
df=pd.DataFrame({'Model':Model[0:246],'Year':Year[0:246],'Price':Price[0:246],'KM_driven':KM_driven[0:246],'Fuel_Type':Fuel_Type[0:246],'Registration':Registration[0:246]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                        Maruti Suzuki Swift DZire VDI  2014    ₹ 4.5 Lakh
# 1                        Maruti Suzuki Wagon R 1.0 VXi  2012   ₹ 2.25 Lakh
# 2                       Maruti Suzuki S-Cross Zeta 1.3  2015   ₹ 6.35 Lakh
# 3                              Maruti Suzuki Swift VDi  2013    ₹ 3.5 Lakh
# 4                              Maruti Suzuki Ciaz ZXI+  2016    ₹ 6.9 Lakh
# 5                       Maruti Suzuki Baleno Delta 1.2  2019    ₹ 6.5 Lakh
# 6                    Maruti Suzuki XL6 Alpha AT Petrol  2019   ₹ 11.2 Lakh
# 7                    Maruti Suzuki Wagon R 1.0 LXi CNG  2011   ₹ 2.25 Lakh
# 8                                Maruti Suzuki SX4 VXi  2009   ₹ 2.35 Lakh
# 9                        Maruti Suzuki Wagon R 1.0 VXi  2010    ₹ 1.9 Lakh
# 10                    Maruti Suzuki Baleno Zeta 1.2 AT  2017    ₹ 6.9 Lakh
# ...

# %%
import selenium
import pandas as pd
import time
# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# importing regex
import re

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-in-delhi/#sc=-1&so=-1&car=10&city=2&pc=2&pn=1"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
pd.set_option("display.max_rows",None)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                             Maruti Suzuki Ertiga ZDi  2015   ₹ 8.35 Lakh
# 1                        Maruti Suzuki Swift Dzire ZDi  2009   ₹ 3.45 Lakh
# 2                        Maruti Suzuki Baleno Zeta 1.3  2018    ₹ 8.4 Lakh
# 3                        Maruti Suzuki Celerio VXi AMT  2015   ₹ 4.49 Lakh
# 4                        Maruti Suzuki Swift DZire VXI  2015   ₹ 4.99 Lakh
# 5            Maruti Suzuki Celerio ZXi AMT [2019-2020]  2019    ₹ 5.9 Lakh
# 6               Maruti Suzuki Alto K10 VXi [2014-2019]  2016    ₹ 4.5 Lakh
# 7                      Maruti Suzuki Vitara Brezza ZXi  2020  ₹ 10.75 Lakh
# 8            Maruti Suzuki Celerio VXi AMT [2017-2019]  2017   ₹ 4.99 Lakh
# 9                   Maruti Suzuki S-Presso Vxi (O) AMT  2020   ₹ 4.99 Lakh
# 10   Maruti Suzuki Ciaz Alpha Hybrid 1.5 AT [2018-2...  2018   ₹ 9.95 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-in-delhi/#sc=-1&so=-1&city=2&pc=2&car=8+10&filterbyadditional=2"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                            Maruti Suzuki Ertiga ZXI+  2017    ₹ 8.5 Lakh
# 1         Maruti Suzuki Swift ZXi Plus AMT [2018-2019]  2018   ₹ 8.35 Lakh
# 2                     Hyundai Creta SX Plus 1.6 Petrol  2019  ₹ 12.85 Lakh
# 3                         Hyundai Elite i20 Sportz 1.2  2018   ₹ 7.35 Lakh
# 4               Maruti Suzuki Alto K10 VXi [2014-2019]  2018   ₹ 3.95 Lakh
# 5                        Maruti Suzuki Swift DZire VXI  2015   ₹ 4.99 Lakh
# 6                         Maruti Suzuki Ritz Vdi BS-IV  2012   ₹ 3.75 Lakh
# 7                  Hyundai Creta 1.6 SX Plus AT Petrol  2018  ₹ 13.45 Lakh
# 8                        Maruti Suzuki Celerio VXi AMT  2015   ₹ 4.49 Lakh
# 9     Hyundai Grand i10 Sports Edition 1.2L Kappa VTVT  2018   ₹ 5.99 Lakh
# 10           Maruti Suzuki Celerio VXi AMT [2017-2019]  2017   ₹ 4.99 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-in-delhi/#sc=-1&so=-1&city=176&pc=176&pn=10&lcr=216&ldr=0&lir=0"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                   Ford EcoSport Titanium + 1.5L TDCi  2018   ₹ 10.9 Lakh
# 1        Toyota Innova Crysta 2.4 VX 8 STR [2016-2020]  2018   ₹ 20.5 Lakh
# 2         Maruti Suzuki Vitara Brezza ZXi Plus AT SHVS  2020  ₹ 11.75 Lakh
# 3                                         Honda City V  2016   ₹ 7.45 Lakh
# 4                  Kia Seltos HTK Plus 1.5 [2019-2020]  2020   ₹ 12.6 Lakh
# 5                               BMW X5 xDrive30d xLine  2020   ₹ 84.9 Lakh
# 6                   Audi S5 Sportback 3.0 TFSI Quattro  2016     ₹ 44 Lakh
# 7                     Volkswagen Vento Highline Diesel  2012   ₹ 4.99 Lakh
# 8                   Skoda Rapid Ambition 1.6 TDI CR MT  2014    ₹ 4.3 Lakh
# 9                         Hyundai i10 Magna 1.2 Kappa2  2010   ₹ 2.65 Lakh
# 10                             Maruti Suzuki Swift VXi  2005   ₹ 2.35 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&filterbyadditional=2&pn=1"
driver.get(url)

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:247],'Year':Year[0:247],'Price':Price[0:247],'KM_driven':KM_driven[0:247],'Fuel_Type':Fuel_Type[0:247],'Registration':Registration[0:247]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                               Tata Hexa XE 4x2 7 STR  2017   ₹ 9.25 Lakh
# 1                         Datsun redi-GO S [2016-2019]  2017    ₹ 2.2 Lakh
# 2     Toyota Innova Crysta 2.8 ZX AT 7 STR [2016-2020]  2017   ₹ 18.9 Lakh
# 3                         Maruti Suzuki Alto LX BS-III  2009   ₹ 1.24 Lakh
# 4              Maruti Suzuki Swift VDi ABS [2014-2017]  2016   ₹ 5.65 Lakh
# 5                             Maruti Suzuki Ertiga Vxi  2014   ₹ 5.25 Lakh
# 6                                Hyundai i20 Magna 1.2  2013   ₹ 2.99 Lakh
# 7                              Honda WR-V VX MT Petrol  2018    ₹ 7.4 Lakh
# 8                                   Honda Brio S (O)MT  2018      ₹ 4 Lakh
# 9                                  Hyundai Xcent S 1.2  2014    ₹ 4.2 Lakh
# 10            Renault Kwid CLIMBER 1.0 AMT [2017-2019]  2018      ₹ 4 Lakh
# ...

# %%
import selenium
import pandas as pd
import time
# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# importing regex
import re

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&filterbyadditional=2&pn=1"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
pd.set_option("display.max_rows",None)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                         Model  Year         Price  \
# 0    Honda Amaze 1.5 VX MT Diesel [2018-2020]  2018    ₹ 8.8 Lakh
# 1                   Honda Amaze 1.2 VX i-VTEC  2013   ₹ 4.05 Lakh
# 2                                Honda City V  2018   ₹ 8.55 Lakh
# 3                         Honda Jazz V Diesel  2016    ₹ 5.9 Lakh
# 4        Honda City VX CVT Petrol [2017-2019]  2017   ₹ 9.85 Lakh
# 5                        Honda City VX Diesel  2015      ₹ 6 Lakh
# 6                         Honda City 1.5 V AT  2011   ₹ 3.85 Lakh
# 7                         Honda Accord 2.4 AT  2011   ₹ 4.95 Lakh
# 8                          Honda Brio S (O)MT  2018      ₹ 4 Lakh
# 9                   Honda Amaze 1.2 SX i-VTEC  2016   ₹ 4.45 Lakh
# 10                    Honda WR-V VX MT Petrol  2018    ₹ 7.4 Lakh
# 11                               Honda City V  2019  ₹ 10.95 Lakh
# 12                               Honda City V  2018   ₹ 9.45 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&filterbyadditional=2&car=1"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)

for i in range(200):
    
    for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
        Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                             Model  Year         Price  \
# 0    BMW 3 Series GT 320d Luxury Line [2014-2016]  2018  ₹ 38.45 Lakh
# 1    BMW 6 Series GT 630i Luxury Line [2018-2019]  2019     ₹ 57 Lakh
# 2                                BMW X1 sDrive20d  2011      ₹ 8 Lakh
# 3                                BMW X1 sDrive20d  2013    ₹ 8.5 Lakh
# 4                     BMW X1 sDrive20d Expedition  2017  ₹ 21.75 Lakh
# 5                               BMW X5 xDrive 30d  2012   ₹ 19.5 Lakh
# 6                         BMW 5 Series 520d Sedan  2012   ₹ 12.9 Lakh
# 7     BMW X5 xDrive30d Pure Experience (5 Seater)  2017   ₹ 44.9 Lakh
# 8                      BMW 3 Series 320d Prestige  2013  ₹ 12.95 Lakh
# 9                                BMW X1 sDrive20d  2013    ₹ 8.5 Lakh
# 10                  BMW 3 Series 320d Luxury Line  2014   ₹ 14.5 Lakh
# 11                         BMW X5 xDrive30d xLine  2020     ₹ 77 Lakh
# ...

# %%
import selenium
import pandas as pd
import time
# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# importing regex
import re

# %%
driver= webdriver.Chrome(r"C:\Users\shobh\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&filterbyadditional=2&pn=1"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
pd.set_option("display.max_rows",None)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                      Mercedes-Benz GLA 200 CDI Style  2015   ₹ 15.5 Lakh
# 1                    Toyota Corolla Altis VL AT Petrol  2015   ₹ 9.75 Lakh
# 2                 Volkswagen Polo Comfortline 1.2L (D)  2013    ₹ 3.5 Lakh
# 3               Hyundai Elite i20 Asta 1.2 [2016-2017]  2019      ₹ 7 Lakh
# 4                        Maruti Suzuki Wagon R 1.0 VXI  2014   ₹ 2.95 Lakh
# 5                  Hyundai Creta 1.6 SX Plus AT Petrol  2016    ₹ 9.9 Lakh
# 6                              Maruti Suzuki Swift LDi  2018   ₹ 4.95 Lakh
# 7                Ford EcoSport Titanium 1.5L Ti-VCT AT  2016   ₹ 6.75 Lakh
# 8              Honda Amaze 1.2 V MT Petrol [2018-2020]  2020   ₹ 7.85 Lakh
# 9                     Ford EcoSport Titanium 1.5L TDCi  2019    ₹ 9.8 Lakh
# 10                    Renault Duster 110 PS RxL Diesel  2014   ₹ 5.25 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&filterbyadditional=1&pn=2&lcr=24&ldr=0&lir=0"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                        Maruti Suzuki Swift DZire VDI  2014    ₹ 4.5 Lakh
# 1                        Maruti Suzuki Celerio VXi AMT  2016   ₹ 4.35 Lakh
# 2                     Hyundai i10 Sportz 1.2 AT Kappa2  2012    ₹ 2.9 Lakh
# 3                                  Honda City V Diesel  2016   ₹ 6.85 Lakh
# 4                           Hyundai Creta S 1.5 Petrol  2021  ₹ 13.85 Lakh
# 5                     Hyundai Elite i20 Sportz 1.2 (O)  2016      ₹ 5 Lakh
# 6                   Maruti Suzuki S-Presso Vxi (O) AMT  2020   ₹ 4.99 Lakh
# 7                     Volkswagen Polo Highline1.2L (D)  2014   ₹ 5.95 Lakh
# 8                                   Honda Brio S (O)MT  2018      ₹ 4 Lakh
# 9                            Hyundai Venue SX 1.5 CRDi  2020  ₹ 11.45 Lakh
# 10                                Honda City VX Diesel  2015      ₹ 6 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&lcr=192&ldr=0&lir=0&car=18"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                        Maruti Suzuki Swift DZire VDI  2014    ₹ 4.5 Lakh
# 1                        Maruti Suzuki Celerio VXi AMT  2016   ₹ 4.35 Lakh
# 2                     Hyundai i10 Sportz 1.2 AT Kappa2  2012    ₹ 2.9 Lakh
# 3                                  Honda City V Diesel  2016   ₹ 6.85 Lakh
# 4                           Hyundai Creta S 1.5 Petrol  2021  ₹ 13.85 Lakh
# 5                     Hyundai Elite i20 Sportz 1.2 (O)  2016      ₹ 5 Lakh
# 6                   Maruti Suzuki S-Presso Vxi (O) AMT  2020   ₹ 4.99 Lakh
# 7                     Volkswagen Polo Highline1.2L (D)  2014   ₹ 5.95 Lakh
# 8                                   Honda Brio S (O)MT  2018      ₹ 4 Lakh
# 9                            Hyundai Venue SX 1.5 CRDi  2020  ₹ 11.45 Lakh
# 10                                Honda City VX Diesel  2015      ₹ 6 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&car=2&pn=2&lcr=24&ldr=0&lir=0"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year        Price  \
# 0                               Chevrolet Cruze LTZ AT  2013   ₹ 5.1 Lakh
# 1                             Chevrolet Beat LS Diesel  2014   ₹ 2.5 Lakh
# 2                               Chevrolet Spark LT 1.0  2012   ₹ 1.5 Lakh
# 3                             Chevrolet Beat LS Petrol  2016   ₹ 3.4 Lakh
# 4                               Chevrolet Spark LS 1.0  2010  ₹ 1.25 Lakh
# 5                   Chevrolet Optra Magnum LT 2.0 TCDi  2008  ₹ 3.35 Lakh
# 6                         Chevrolet Enjoy 1.3 LS 7 STR  2013     ₹ 5 Lakh
# 7                               Chevrolet Cruze LTZ AT  2012  ₹ 5.25 Lakh
# 8                             Chevrolet Beat LS Diesel  2012  ₹ 2.25 Lakh
# 9                                  Chevrolet Cruze LTZ  2010     ₹ 3 Lakh
# 10                        Chevrolet Enjoy 1.3 LS 7 STR  2013   ₹ 4.9 Lakh
# 11                             Chevrolet Sail 1.3 Base  2014  ₹ 2.96 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-for-sale/#sc=-1&so=-1&car=56"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                        Model  Year        Price    KM_driven  \
# 0               Datsun redi-GO S [2016-2019]  2016   ₹ 2.6 Lakh    40,820 km
# 1                           Datsun GO Plus T  2017  ₹ 3.25 Lakh    34,325 km
# 2           Datsun redi-GO T (O) [2016-2019]  2017  ₹ 3.45 Lakh    35,000 km
# 3           Datsun redi-GO T (O) [2016-2019]  2017  ₹ 3.46 Lakh    23,142 km
# 4               Datsun redi-GO S [2016-2019]  2017   ₹ 2.2 Lakh    29,210 km
# 5       Datsun redi-GO S 1.0 AMT [2018-2019]  2018   ₹ 4.6 Lakh    16,000 km
# 6                    Datsun redi-GO T(O) 1.0  2019  ₹ 3.75 Lakh    27,411 km
# 7           Datsun redi-GO T (O) [2016-2019]  2017  ₹ 3.11 Lakh     6,900 km
# 8                            Datsun GO T (O)  2018   ₹ 2.9 Lakh    10,617 km
# 9           Datsun redi-GO T (O) [2016-2019]  2016  ₹ 2.05 Lakh    64,968 km
# 10          Datsun redi-GO T (O) [2016-2019]  2017  ₹ 2.37 Lakh    24,719 km
# ...

# %%
url="https://www.carwale.com/used/cars-in-delhi/#city=10&pc=10&sc=-1&so=-1&filterbyadditional=2&car=45"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                            Renault Duster 110 PS RxL  2016      ₹ 5 Lakh
# 1                            Renault Duster RXL Petrol  2017    ₹ 5.7 Lakh
# 2                         Renault Kwid 1.0 RXL Edition  2017      ₹ 3 Lakh
# 3                         Renault Kwid RXL [2015-2019]  2016   ₹ 2.75 Lakh
# 4                               Renault Fluence 2.0 E4  2012   ₹ 3.25 Lakh
# 5                     Renault Kwid 1.0 RXL [2017-2019]  2016    ₹ 2.9 Lakh
# 6                             Renault Kwid 1.0 RXT Opt  2019   ₹ 3.75 Lakh
# 7                         Renault Kwid RXL [2015-2019]  2017   ₹ 3.75 Lakh
# 8             Renault Kwid CLIMBER 1.0 AMT [2017-2019]  2020   ₹ 4.95 Lakh
# 9                      Renault Duster 85 PS RxL Diesel  2014   ₹ 4.45 Lakh
# 10            Renault Kwid 1.0 RXT AMT Opt [2016-2019]  2017   ₹ 3.25 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-in-delhi/#sc=-1&so=-1&city=10&pc=10&car=8+45"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                                    Hyundai i10 Magna  2008    ₹ 1.4 Lakh
# 1                    Hyundai Verna SX Plus 1.6 CRDi AT  2018  ₹ 10.99 Lakh
# 2                  Hyundai Creta 1.6 SX Plus AT Petrol  2017  ₹ 10.99 Lakh
# 3                         Renault Kwid 1.0 RXL Edition  2017      ₹ 3 Lakh
# 4                 Hyundai Santro Magna AMT [2018-2020]  2019    ₹ 4.9 Lakh
# 5                         Hyundai Creta SX 1.6 AT CRDi  2018  ₹ 14.75 Lakh
# 6    Hyundai Grand i10 Sportz (O) AT 1.2 Kappa VTVT...  2017    ₹ 5.8 Lakh
# 7                  Hyundai Creta 1.6 SX Plus AT Petrol  2018  ₹ 12.65 Lakh
# 8                               Hyundai Xcent Base 1.2  2015   ₹ 3.95 Lakh
# 9              Hyundai i10 Magna 1.1 iRDE2 [2010-2017]  2016   ₹ 3.65 Lakh
# 10           Hyundai Grand i10 Sports Edition 1.1 CRDi  2014    ₹ 3.2 Lakh
# ...

# %%
url="https://www.carwale.com/used/cars-in-delhi/#sc=-1&so=-1&city=10&pc=10&car=9+45"
driver.get(url)

# %%
time.sleep(2)  # Allow 2 seconds for the web page to open
scroll_pause_time = 1
screen_height = driver.execute_script("return window.screen.height;")   # get the screen height of the web
i = 1

while True:
    # scroll one screen height each time
    driver.execute_script("window.scrollTo(0, {screen_height}*{i});".format(screen_height=screen_height, i=i))  
    i += 1
    time.sleep(scroll_pause_time)
    # update scroll height each time after scrolled, as the scroll height can change after we scrolled the page
    scroll_height = driver.execute_script("return document.body.scrollHeight;")  
    # Break the loop when the height we need to scroll to is larger than the total scroll height
    if (screen_height) * i > scroll_height:
        break

# %%
Model=[]
Year=[]
Last_service=[]
Fuel_Type=[]
Price=[]
Registration=[]
Owner_details=[]
KM_driven=[]

time.sleep(4)


    
for j in driver.find_elements_by_xpath("//span[@class='spancarname card-detail-block__title-text-with-year']"):
    Model.append(j.text)
        
for l in driver.find_elements_by_xpath("//span[@class='slYear card-detail-block__title-text-with-year']"):
        Year.append(l.text)
for m in driver.find_elements_by_xpath("//span[@class='rupee-lac slprice']"):
        Price.append(m.text)

for i in driver.find_elements_by_xpath("//span[@class='slkms vehicle-data__item']"):
        KM_driven.append(i.text)
        
for n in driver.find_elements_by_xpath("//span[@class='fuel vehicle-data__item']"):
        Fuel_Type.append(n.text)
        
for k in driver.find_elements_by_xpath("//span[@class='cityName vehicle-data__item']"):
        Registration.append(k.text)

# %%
df=pd.DataFrame({'Model':Model[0:245],'Year':Year[0:245],'Price':Price[0:245],'KM_driven':KM_driven[0:245],'Fuel_Type':Fuel_Type[0:245],'Registration':Registration[0:245]})
#printing dataframe
df
# Out:
#                                                  Model  Year         Price  \
# 0                         Renault Kwid 1.0 RXL Edition  2017      ₹ 3 Lakh
# 1                            Renault Duster 110 PS RxL  2016      ₹ 5 Lakh
# 2                    Mahindra Scorpio S7 140 2WD 7 STR  2018  ₹ 12.91 Lakh
# 3                         Renault Kwid 1.0 RXL Edition  2017   ₹ 2.95 Lakh
# 4                             Mahindra Scorpio S6 Plus  2015   ₹ 8.15 Lakh
# 5         Mahindra Thar LX 4-STR Convertible Diesel MT  2021   ₹ 16.9 Lakh
# 6                         Renault Kwid RXL [2015-2019]  2016   ₹ 2.75 Lakh
# 7                               Renault Fluence 1.5 E2  2012   ₹ 1.99 Lakh
# 8                       Mahindra KUV100 NXT K8 D 6 STR  2017   ₹ 4.35 Lakh
# 9                                 Mahindra Scorpio S10  2015   ₹ 9.95 Lakh
# 10                            Mahindra Scorpio S4 Plus  2016    ₹ 8.4 Lakh
# ...
